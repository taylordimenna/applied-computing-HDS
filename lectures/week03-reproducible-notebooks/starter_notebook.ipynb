# %% [markdown]
# # Week 3 Practical — Starter Notebook (Jupyter)
#
# This notebook has **one bug**. It was "tested" by running cells out
# of order while writing it, so it happened to work in that session —
# but the order on the page doesn't match the order the cells were
# actually run in.
#
# **Your task:**
# 1. Run **Restart Kernel and Run All Cells** and watch it fail.
# 2. Diagnose the error with an AI assistant (paste the exact error text).
# 3. Fix it, then **Restart & Run All** again until it completes clean, top to bottom.
# 4. Add one new Markdown cell and one new code cell of your own below the last cell.
# 5. Restart & Run All one more time to confirm your addition doesn't break anything.
# 6. Export this notebook to HTML (see `practical.md` for the command).

# %%
import pandas as pd
patients = pd.DataFrame({
    "patient_id": ["P001", "P002", "P003", "P004", "P005"],
    "age": [54, 61, 47, 72, 39],
    "site": ["DC", "MD", "DC", "VA", "MD"],
})
patients.describe()
# Out:
#              age
# count   5.000000
# mean   54.600000
# std    12.700394
# min    39.000000
# 25%    47.000000
# 50%    54.000000
# 75%    61.000000
# max    72.000000

# %% [markdown]
# ## Setup
#
# (this belongs above the cell that uses it — that's the bug)

# %%
import pandas as pd

# %% [markdown]
# ## Summarize by site

# %%
patients.groupby("site")["age"].mean()
# Out:
# site
# DC    50.5
# MD    50.0
# VA    72.0
# Name: age, dtype: float64

# %% [markdown]
# ## What the summary shows
#
# Put my written intrepretation here
